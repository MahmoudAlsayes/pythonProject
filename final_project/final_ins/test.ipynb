# %%
import numpy as np
import pandas as pd 
with open("2_1.txt", "r") as file:
    data=file.read()

# %%
data
# Out:
# '2438.0\t2438.0\t2438.0\t2455.0\t2455.0\t2384.0\t2384.0\t2384.0\t2418.0\t2418.0\t2415.0\t2415.0\t2415.0\t2398.0\t2398.0\t2388.0\t2388.0\t2388.0\t2340.0\t2340.0\t2340.0\t2340.0\t2340.0\t2399.0\t2399.0\t2353.0\t2353.0\t2353.0\t2318.0\t2318.0\t2324.0\t2324.0\t2324.0\t2283.0\t2283.0\t2333.0\t2333.0\t2333.0\t2326.0\t2326.0\t2274.0\t2274.0\t2274.0\t2309.0\t2309.0\t2224.0\t2224.0\t2224.0\t2288.0\t2288.0\t2268.0\t2268.0\t2268.0\t2250.0\t2250.0\t2251.0\t2251.0\t2251.0\t2166.0\t2166.0\t2189.0\t2189.0\t2189.0\t2212.0\t2212.0\t2141.0\t2141.0\t2141.0\t2121.0\t2121.0\t2175.0\t2175.0\t2175.0\t2099.0\t2099.0\t2098.0\t2098.0\t2098.0\t2146.0\t2146.0\t2068.0\t2068.0\t2068.0\t2116.0\t2116.0\t2051.0\t2051.0\t2051.0\t2112.0\t2112.0\t2069.0\t2069.0\t2069.0\t2045.0\t2045.0\t2031.0\t2031.0\t2031.0\t2081.0\t2081.0\t2083.0\t2083.0\t2083.0\t2060.0\t2060.0\t2019.0\t2019.0\t2019.0\t2063.0\t2063.0\t2004.0\t2004.0\t2004.0\t1996.0\t1996.0\t2035.0\t2035.0\t2035.0\t1967.0\t1967.0\t2034.0\t2034.0\t2034.0\t1975.0\t1975.
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import heartpy as hp

data,timer=hp.load_exampledata(0)
plt.figure(figsize=(15,4))
plt.plot(data)
plt.show()

# %%
wd, m = hp.process(data, sample_rate = 100.0)

# %%
#set large figure
plt.figure(figsize=(12,4))

#call plotter
hp.plotter(wd, m)

#display measures computed
for measure in m.keys():
    print('%s: %f' %(measure, m[measure]))

plt.show()
# Out:
# bpm: 58.898848
# ibi: 1018.695652
# sdnn: 65.760061
# sdsd: 34.866925
# rmssd: 64.737231
# pnn20: 0.863636
# pnn50: 0.409091
# hr_mad: 40.000000
# sd1: 45.758077
# sd2: 82.926832
# s: 11921.000816
# sd1/sd2: 0.551789
# breathingrate: 0.170721

# %%
data, timer = hp.load_exampledata(1)

plt.figure(figsize=(12,4))
plt.plot(data)
plt.show()

# %%
sample_rate = hp.get_samplerate_mstimer(timer)

wd, m = hp.process(data, sample_rate)

#plot
plt.figure(figsize=(12,4))
hp.plotter(wd, m)
result={}
#display measures computed
for measure in m.keys():
    print('%s: %f' %(measure, m[measure]))
    result[measure] = m[measure]
# Out:
# bpm: 62.376304
# ibi: 961.903744
# sdnn: 64.613519
# sdsd: 29.871930
# rmssd: 57.069746
# pnn20: 0.797297
# pnn50: 0.486486
# hr_mad: 47.010333
# sd1: 40.344402
# sd2: 81.621935
# s: 10345.227446
# sd1/sd2: 0.494284
# breathingrate: 0.266667

# %%
result
# Out:
# {'bpm': np.float64(62.376303658082314),
#  'ibi': np.float64(961.9037435897436),
#  'sdnn': np.float64(64.61351904709534),
#  'sdsd': np.float64(29.871930288503076),
#  'rmssd': np.float64(57.06974592070174),
#  'pnn20': 0.7972972972972973,
#  'pnn50': 0.4864864864864865,
#  'hr_mad': np.float64(47.01033333333328),
#  'sd1': np.float64(40.34440235829248),
#  'sd2': np.float64(81.62193459899746),
#  's': np.float64(10345.227445505197),
#  'sd1/sd2': np.float64(0.4942838289303182),
#  'breathingrate': np.float64(0.26666666666666666)}

# %%
df= pd.DataFrame([result])

# %%
df
# Out:
#          bpm         ibi       sdnn      sdsd      rmssd     pnn20     pnn50  \
# 0  62.376304  961.903744  64.613519  29.87193  57.069746  0.797297  0.486486
#
#       hr_mad        sd1        sd2             s   sd1/sd2  breathingrate
# 0  47.010333  40.344402  81.621935  10345.227446  0.494284       0.266667

# %%
data_set=pd.read_csv("PPG-BP dataset.csv")

# %%
data_set
# Out:
#     Cardiovascular Dataset Information File  Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                                      Num.  subject_ID   Sex(M/F)  Age(year)
# 1                                         1           2     Female         45
# 2                                         2           3     Female         50
# 3                                         3           6     Female         47
# 4                                         4           8       Male         45
# ..                                      ...         ...        ...        ...
# 215                                     215         415       Male         24
# 216                                     216         416     Female         25
# 217                                     217         417       Male         25
# 218                                     218         418       Male         25
# 219                                     219         419       Male         24
#
# ...

# %%
# result=pd.Series(result)
# result

# %%
result=pd.DataFrame(result,index=data_set.index)

# %%
result
# Out:
#            bpm         ibi       sdnn      sdsd      rmssd     pnn20  \
# 0    62.376304  961.903744  64.613519  29.87193  57.069746  0.797297
# 1    62.376304  961.903744  64.613519  29.87193  57.069746  0.797297
# 2    62.376304  961.903744  64.613519  29.87193  57.069746  0.797297
# 3    62.376304  961.903744  64.613519  29.87193  57.069746  0.797297
# 4    62.376304  961.903744  64.613519  29.87193  57.069746  0.797297
# ..         ...         ...        ...       ...        ...       ...
# 215  62.376304  961.903744  64.613519  29.87193  57.069746  0.797297
# 216  62.376304  961.903744  64.613519  29.87193  57.069746  0.797297
# 217  62.376304  961.903744  64.613519  29.87193  57.069746  0.797297
# 218  62.376304  961.903744  64.613519  29.87193  57.069746  0.797297
# 219  62.376304  961.903744  64.613519  29.87193  57.069746  0.797297
#
#         pnn50     hr_mad        sd1        sd2             s   sd1/sd2  \
# ...

# %%
# data_set[result.values]=result

# %%
data_set
# Out:
#     Cardiovascular Dataset Information File  Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                                      Num.  subject_ID   Sex(M/F)  Age(year)
# 1                                         1           2     Female         45
# 2                                         2           3     Female         50
# 3                                         3           6     Female         47
# 4                                         4           8       Male         45
# ..                                      ...         ...        ...        ...
# 215                                     215         415       Male         24
# 216                                     216         416     Female         25
# 217                                     217         417       Male         25
# 218                                     218         418       Male         25
# 219                                     219         419       Male         24
#
# ...

# %%
data_set[result]=np.nan

# %%
data_set
# Out:
#     Cardiovascular Dataset Information File  Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                                      Num.  subject_ID   Sex(M/F)  Age(year)
# 1                                         1           2     Female         45
# 2                                         2           3     Female         50
# 3                                         3           6     Female         47
# 4                                         4           8       Male         45
# ..                                      ...         ...        ...        ...
# 215                                     215         415       Male         24
# 216                                     216         416     Female         25
# 217                                     217         417       Male         25
# 218                                     218         418       Male         25
# 219                                     219         419       Male         24
#
# ...

# %%
data_set.at[0,13:28]=result
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File J:\telegram course\Projects\pythonProject\.venv\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: slice(13, 28, None)
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# ...
